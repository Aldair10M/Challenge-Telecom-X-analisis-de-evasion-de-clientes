# %% [markdown]
# # **Challenge Telecom X**

# %%
import pandas as pd;

# %% [markdown]
# #📌 Extracción

# %%
# Paso 1: Cargar los datos desde la API
api = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json';
datos = pd.read_json(api);
datos
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
# Paso 2: Normalizar los datos
datos_normalizados = pd.json_normalize(datos.to_dict(orient='records'), sep='_')
# Paso 3 (opcional): Visualizar
datos_normalizados
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %% [markdown]
# #🔧 Transformación

# %%
# A través de info() vemo un resumen general del DataFrame: número de columnas, valores nulos y tipos de datos
datos_normalizados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
# ...

# %%
# A través de dtypes vemos sólo los tipos de datos por columna
print("\nTipos de datos:")
print(datos_normalizados.dtypes)
# Out:
# Tipos de datos:
# customerID                    object
# Churn                         object
# customer_gender               object
# customer_SeniorCitizen         int64
# customer_Partner              object
# customer_Dependents           object
# customer_tenure                int64
# phone_PhoneService            object
# phone_MultipleLines           object
# internet_InternetService      object
# internet_OnlineSecurity       object
# internet_OnlineBackup         object
# internet_DeviceProtection     object
# internet_TechSupport          object
# internet_StreamingTV          object
# internet_StreamingMovies      object
# account_Contract              object
# account_PaperlessBilling      object
# account_PaymentMethod         object
# account_Charges_Monthly      float64
# account_Charges_Total         object
# dtype: object

# %%
# Convertimos la columna 'account_Charges_Total' a numérico, ya que es de tipo object (String)
datos_normalizados['account_Charges_Total'] = pd.to_numeric(datos_normalizados['account_Charges_Total'], errors='coerce')

# %%
# Re-verificamos los tipos
print("\nTipos de datos:")
print(datos_normalizados.dtypes)
# Out:
# Tipos de datos:
# customerID                    object
# Churn                         object
# customer_gender               object
# customer_SeniorCitizen         int64
# customer_Partner              object
# customer_Dependents           object
# customer_tenure                int64
# phone_PhoneService            object
# phone_MultipleLines           object
# internet_InternetService      object
# internet_OnlineSecurity       object
# internet_OnlineBackup         object
# internet_DeviceProtection     object
# internet_TechSupport          object
# internet_StreamingTV          object
# internet_StreamingMovies      object
# account_Contract              object
# account_PaperlessBilling      object
# account_PaymentMethod         object
# account_Charges_Monthly      float64
# account_Charges_Total        float64
# dtype: object

# %%
# 1. Verificamos los valores nulos
print("Valores nulos por columna:")
print(datos_normalizados.isnull().sum())
# Out:
# Valores nulos por columna:
# customerID                    0
# Churn                         0
# customer_gender               0
# customer_SeniorCitizen        0
# customer_Partner              0
# customer_Dependents           0
# customer_tenure               0
# phone_PhoneService            0
# phone_MultipleLines           0
# internet_InternetService      0
# internet_OnlineSecurity       0
# internet_OnlineBackup         0
# internet_DeviceProtection     0
# internet_TechSupport          0
# internet_StreamingTV          0
# internet_StreamingMovies      0
# account_Contract              0
# account_PaperlessBilling      0
# account_PaymentMethod         0
# account_Charges_Monthly       0
# account_Charges_Total        11
# dtype: int64

# %%
# 2. Verificamos las filas duplicados
duplicados = datos_normalizados.duplicated().sum()
print(f"Número de filas duplicadas: {duplicados}")

## si es que existen filas duplicadas:
# datos_normalizados = datos_normalizados.drop_duplicates()
# Out:
# Número de filas duplicadas: 0

# %%
# 3. Verificamos y limpiamos los valores inconsistentes en categorías
print("\nValores únicos en 'Churn':", datos_normalizados['Churn'].unique())
print("Valores únicos en 'customer_gender':", datos_normalizados['customer_gender'].unique())
print("Valores únicos en 'customer_Partner':", datos_normalizados['customer_Partner'].unique())
print("Valores únicos en 'phone_PhoneService':", datos_normalizados['phone_PhoneService'].unique())
print("Valores únicos en 'account_Contract':", datos_normalizados['account_Contract'].unique())
print("Valores únicos en 'account_PaperlessBilling':", datos_normalizados['account_PaperlessBilling'].unique())
# Out:
# Valores únicos en 'Churn': ['No' 'Yes' '']
# Valores únicos en 'customer_gender': ['Female' 'Male']
# Valores únicos en 'customer_Partner': ['Yes' 'No']
# Valores únicos en 'phone_PhoneService': ['Yes' 'No']
# Valores únicos en 'account_Contract': ['One year' 'Month-to-month' 'Two year']
# Valores únicos en 'account_PaperlessBilling': ['Yes' 'No']

# %%
# Eliminar filas con 'Churn' vacío (string vacío)
datos_normalizados = datos_normalizados[datos_normalizados['Churn'] != '']
print("Valores únicos en 'Churn' (post-limpieza):", datos_normalizados['Churn'].unique())
# Out:
# Valores únicos en 'Churn' (post-limpieza): ['no' 'yes']

# %%
# Normalizar strings
datos_normalizados['Churn'] = datos_normalizados['Churn'].str.lower().str.strip()
datos_normalizados['customer_gender'] = datos_normalizados['customer_gender'].str.lower().str.strip()
datos_normalizados['customer_Partner'] = datos_normalizados['customer_Partner'].str.lower().str.strip()
datos_normalizados['phone_PhoneService'] = datos_normalizados['phone_PhoneService'].str.lower().str.strip()
datos_normalizados['account_Contract'] = datos_normalizados['account_Contract'].str.lower().str.strip()
datos_normalizados['account_PaperlessBilling'] = datos_normalizados['account_PaperlessBilling'].str.lower().str.strip()

# %%
print("\nValores únicos en 'Churn':", datos_normalizados['Churn'].unique())
print("Valores únicos en 'customer_gender':", datos_normalizados['customer_gender'].unique())
print("Valores únicos en 'customer_Partner':", datos_normalizados['customer_Partner'].unique())
print("Valores únicos en 'phone_PhoneService':", datos_normalizados['phone_PhoneService'].unique())
print("Valores únicos en 'account_Contract':", datos_normalizados['account_Contract'].unique())
print("Valores únicos en 'account_PaperlessBilling':", datos_normalizados['account_PaperlessBilling'].unique())
# Out:
# Valores únicos en 'Churn': ['no' 'yes']
# Valores únicos en 'customer_gender': ['female' 'male']
# Valores únicos en 'customer_Partner': ['yes' 'no']
# Valores únicos en 'phone_PhoneService': ['yes' 'no']
# Valores únicos en 'account_Contract': ['one year' 'month-to-month' 'two year']
# Valores únicos en 'account_PaperlessBilling': ['yes' 'no']

# %%
# 4. Eliminamos filas con 'account_Charges_Total' nulos
datos_normalizados = datos_normalizados.dropna(subset=['account_Charges_Total'])

# %%
print("Valores nulos por columna:")
print(datos_normalizados.isnull().sum())
# Out:
# Valores nulos por columna:
# customerID                   0
# Churn                        0
# customer_gender              0
# customer_SeniorCitizen       0
# customer_Partner             0
# customer_Dependents          0
# customer_tenure              0
# phone_PhoneService           0
# phone_MultipleLines          0
# internet_InternetService     0
# internet_OnlineSecurity      0
# internet_OnlineBackup        0
# internet_DeviceProtection    0
# internet_TechSupport         0
# internet_StreamingTV         0
# internet_StreamingMovies     0
# account_Contract             0
# account_PaperlessBilling     0
# account_PaymentMethod        0
# account_Charges_Monthly      0
# account_Charges_Total        0
# dtype: int64

# %%
# 1. Crear la columna "Cuentas_Diarias"
datos_normalizados['Cuentas_Diarias'] = datos_normalizados['account_Charges_Monthly'] / 30

# 2. Convertir "yes"/"no" a 1 y 0
cols_binarias = [col for col in datos_normalizados.columns if datos_normalizados[col].isin(['yes', 'no']).all()]
for col in cols_binarias:
    datos_normalizados[col] = datos_normalizados[col].map({'yes': 1, 'no': 0})

# 3. Renombrar algunas columnas para facilitar la comprensión
datos_normalizados = datos_normalizados.rename(columns={
    'Churn': 'Evasion',
    'customer_gender': 'Genero',
    'customer_SeniorCitizen': 'Adulto_Mayor',
    'customer_Partner': 'Tiene_Pareja',
    'customer_Dependents': 'Tiene_Dependientes',
    'customer_tenure': 'Meses_Cliente',
    'account_Charges_Monthly': 'Facturacion_Mensual',
    'account_Charges_Total': 'Facturacion_Total',
    'account_Contract': 'Tipo_Contrato'
})

# %%
datos_normalizados
# Out:
#       customerID  Evasion  Genero  Adulto_Mayor  Tiene_Pareja  \
# 0     0002-ORFBO        0  female             0             1
# 1     0003-MKNFE        0    male             0             0
# 2     0004-TLHLJ        1    male             0             0
# 3     0011-IGKFF        1    male             1             1
# 4     0013-EXCHZ        1  female             1             1
# ...          ...      ...     ...           ...           ...
# 7262  9987-LUTYD        0  female             0             0
# 7263  9992-RRAMN        1    male             0             1
# 7264  9992-UJOEL        0    male             0             0
# 7265  9993-LHIEB        0    male             0             1
# 7266  9995-HOTOH        0    male             0             1
#
#      Tiene_Dependientes  Meses_Cliente  phone_PhoneService  \
# 0                   Yes              9                   1
# 1                    No              9                   1
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
# Análisis descriptivo de las columnas numéricas
datos_normalizados.describe()
# Out:
#            Evasion  Adulto_Mayor  Tiene_Pareja  Meses_Cliente  \
# count  7032.000000   7032.000000   7032.000000    7032.000000
# mean      0.265785      0.162400      0.482509      32.421786
# std       0.441782      0.368844      0.499729      24.545260
# min       0.000000      0.000000      0.000000       1.000000
# 25%       0.000000      0.000000      0.000000       9.000000
# 50%       0.000000      0.000000      0.000000      29.000000
# 75%       1.000000      0.000000      1.000000      55.000000
# max       1.000000      1.000000      1.000000      72.000000
#
#        phone_PhoneService  account_PaperlessBilling  Facturacion_Mensual  \
# count         7032.000000               7032.000000          7032.000000
# mean             0.903299                  0.592719            64.798208
# std              0.295571                  0.491363            30.085974
# min              0.000000                  0.000000            18.250000
# ...

# %%
# Ver media y mediana de 'Facturacion_Mensual' y 'Cuentas_Diarias'
print("Media facturación mensual:", datos_normalizados['Facturacion_Mensual'].mean())
print("Mediana facturación mensual:", datos_normalizados['Facturacion_Mensual'].median())

print("Media cuentas diarias:", datos_normalizados['Cuentas_Diarias'].mean())
print("Mediana cuentas diarias:", datos_normalizados['Cuentas_Diarias'].median())
# Out:
# Media facturación mensual: 64.79820819112628
# Mediana facturación mensual: 70.35
# Media cuentas diarias: 2.1599402730375425
# Mediana cuentas diarias: 2.3449999999999998

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración de estilo
sns.set(style="whitegrid")

# Conteo de valores
plt.figure(figsize=(6,4))
sns.countplot(x='Evasion', data=datos_normalizados, palette='Set2')

plt.title('Distribución de Evasión de Clientes (Churn)')
plt.xlabel('Evasión (0 = No, 1 = Sí)')
plt.ylabel('Número de Clientes')
plt.xticks([0, 1], ['No se fue', 'Sí se fue'])
plt.show()
# Out:
# <ipython-input-29-769653814>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Evasion', data=datos_normalizados, palette='Set2')

# %%
# Pie chart
evasion_counts = datos_normalizados['Evasion'].value_counts()
labels = ['No se fue', 'Sí se fue']
colors = ['skyblue', 'salmon']

plt.figure(figsize=(6,6))
plt.pie(evasion_counts, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.title('Proporción de Evasión de Clientes')
plt.axis('equal')
plt.show()

# %%
# Evasión por Género
plt.figure(figsize=(6,4))
sns.countplot(x='Genero', hue='Evasion', data=datos_normalizados, palette='Set2')
plt.title('Evasión por Género')
plt.xlabel('Género')
plt.ylabel('Cantidad de clientes')
plt.legend(title='Evasión', labels=['No', 'Sí'])
plt.show()

# Evasión por Tipo de Contrato
plt.figure(figsize=(7,4))
sns.countplot(x='Tipo_Contrato', hue='Evasion', data=datos_normalizados, palette='Set1')
plt.title('Evasión por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Cantidad de clientes')
plt.legend(title='Evasión', labels=['No', 'Sí'])
plt.xticks(rotation=15)
plt.show()

# Evasión por Método de Pago
plt.figure(figsize=(10,4))
sns.countplot(x='account_PaymentMethod', hue='Evasion', data=datos_normalizados, palette='Set3')
plt.title('Evasión por Método de Pago')
plt.xlabel('Método de Pago')
plt.ylabel('Cantidad de clientes')
plt.legend(title='Evasión', labels=['No', 'Sí'])
plt.xticks(rotation=45)
plt.show()

# %%
# Tiempo de permanencia vs Evasión
plt.figure(figsize=(6,4))
sns.boxplot(x='Evasion', y='Meses_Cliente', data=datos_normalizados, palette='Pastel1')
plt.title('Meses como Cliente vs Evasión')
plt.xlabel('Evasión (0 = No, 1 = Sí)')
plt.ylabel('Meses como Cliente')
plt.show()

# Total Facturado vs Evasión
plt.figure(figsize=(6,4))
sns.boxplot(x='Evasion', y='Facturacion_Total', data=datos_normalizados, palette='Pastel2')
plt.title('Facturación Total vs Evasión')
plt.xlabel('Evasión (0 = No, 1 = Sí)')
plt.ylabel('Facturación Total')
plt.show()
# Out:
# <ipython-input-32-3948898151>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Evasion', y='Meses_Cliente', data=datos_normalizados, palette='Pastel1')
# <ipython-input-32-3948898151>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Evasion', y='Facturacion_Total', data=datos_normalizados, palette='Pastel2')

# %% [markdown]
# #📄Informe final

# %% [markdown]
# # 📊 Informe Final - Análisis de Evasión de Clientes en Telecom X
#
# ## 🔹 Introducción
# Telecom X enfrenta una alta tasa de cancelación de servicios por parte de sus clientes. El objetivo de este análisis fue comprender mejor los factores que influyen en la evasión de clientes (Churn), con el fin de aportar información valiosa para estrategias de retención.
#
# ## 🔹 Limpieza y Tratamiento de Datos
# - Se importaron datos desde una API en formato JSON.
# - Se normalizó la estructura jerárquica de los datos para convertirla en un DataFrame plano.
# - Se revisaron los tipos de datos y se convirtieron valores mal tipados como `account_Charges_Total`.
# - Se eliminaron valores nulos e inconsistencias, como cadenas vacías en la variable 'Churn'.
# - Se transformaron respuestas categóricas ("yes"/"no") a valores binarios (1/0).
# - Se creó una nueva columna `Cuentas_Diarias` a partir de la facturación mensual.
#
# ## 🔹 Análisis Exploratorio de Datos
# - Se realizó un análisis descriptivo para conocer medias, medianas y desviaciones estándar.
# - Se observó que el 26% de los clientes abandonaron el servicio (`Churn` = "yes").
# - Visualizaciones mostraron:
#   - Mayor evasión en contratos `month-to-month`.
#   - Usuarios sin pareja o dependientes tienen ligeramente mayor evasión.
#   - Métodos de pago como `electronic check` se asocian con más evasión.
#   - Clientes con menor tiempo de permanencia (`Meses_Cliente`) y menor gasto (`Facturación_Total`) tienden a cancelar más.
#
# ## 🔹 Conclusiones e Insights
# - El tipo de contrato es un fuerte predictor de evasión: los contratos mensuales tienen más riesgo de churn.
# - Los clientes con menor historial y facturación total son más propensos a cancelar.
# - Variables como `PaperlessBilling` o `Método de Pago` también tienen relación con el churn.
# - Factores demográficos como género o tener pareja tienen influencia moderada.
#
# ## 🔹 Recomendaciones
# - Incentivar contratos de mayor duración con promociones o descuentos.
# - Identificar y retener clientes de bajo tenure con campañas personalizadas.
# - Mejorar la experiencia de facturación electrónica, dado que se asocia a mayor evasión.
# - Segmentar clientes por riesgo y aplicar modelos predictivos para acciones proactivas de retención.
#
# ✅ Este análisis brinda un punto de partida sólido para que el equipo de Data Science construya modelos de predicción y la empresa pueda tomar decisiones basadas en datos para reducir el churn."""

# %% [markdown]
# # ¡EXTRA!

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Seleccionamos columnas numéricas para el análisis de correlación
datos_numericos = datos_normalizados.select_dtypes(include=['int64', 'float64'])

# Agregamos la variable objetivo 'Evasion' convertida a binaria
datos_numericos['Evasion'] = datos_normalizados['Evasion'].map({'yes': 1, 'no': 0})

# Calculamos la matriz de correlación
correlaciones = datos_numericos.corr()

# Visualizamos la matriz de correlación
plt.figure(figsize=(12, 8))
sns.heatmap(correlaciones, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=.5)
plt.title("Matriz de Correlación entre Variables Numéricas")
plt.show()
